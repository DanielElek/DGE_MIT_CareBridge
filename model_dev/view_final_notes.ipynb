# %%
import pandas as pd

# %%
notes500 = pd.read_csv("evaluated_soap_notes.csv")
notes500
# Out:
#                                            input_text  \
# 0   Doctor: Hello, how are you today?\n\nPatient: ...
# 1   Doctor: Good morning. I see you’re here for so...
# 2   **Doctor:** Hello, how are you today?  \n**Pat...
# 3   Doctor: Hello, how are you today?\n\nPatient: ...
# 4   Doctor: Hello, how can I help you today?\n\nPa...
# 5   Doctor: Hello, how are you today?\n\nPatient: ...
# 6   Doctor: Hello, how are you today?\n\nPatient: ...
# 7   Doctor: Hello, how are you today?\n\nPatient: ...
# 8   Doctor: Hello, how are you today?\n\nPatient: ...
# 9   Doctor: Hello! I’m Dr. Aris. It’s good to see ...
# 10  Doctor: Hello, how are you feeling today?\n\nP...
# 11  Doctor: Hello, how are you today?\n\nPatient: ...
# 12  Doctor: Hello, how are you today?\n\nPatient: ...
#
#                                              response  \
# 0   {"subjective": "Patient reports significant co...
# 1   ```json\n{\n  "subjective": "Patient reports a...
# ...

# %%
notes200 = pd.read_csv("evaluated_soap_notes_200.csv")
notes200
# Out:
#                                            input_text  \
# 0   Doctor: Hello, how are you today?\n\nPatient: ...
# 1   Doctor: Good morning. I see you’re here for so...
# 2   **Doctor:** Hello, how are you today?  \n**Pat...
# 3   Doctor: Hello, how are you today?\n\nPatient: ...
# 4   Doctor: Hello, how can I help you today?\n\nPa...
# 5   Doctor: Hello, how are you today?\n\nPatient: ...
# 6   Doctor: Hello, how are you today?\n\nPatient: ...
# 7   Doctor: Hello, how are you today?\n\nPatient: ...
# 8   Doctor: Hello, how are you today?\n\nPatient: ...
# 9   Doctor: Hello! I’m Dr. Aris. It’s good to see ...
# 10  Doctor: Hello, how are you feeling today?\n\nP...
# 11  Doctor: Hello, how are you today?\n\nPatient: ...
# 12  Doctor: Hello, how are you today?\n\nPatient: ...
#
#                                              response  \
# 0   Subjective: Patient reports significant conges...
# 1   Subjective: Patient reports a heavy cough with...
# ...
